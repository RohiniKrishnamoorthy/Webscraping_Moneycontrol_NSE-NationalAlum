# %% [markdown]
# ### Import libraries

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import smtplib
import time
import datetime

# %%
URL ="https://www.moneycontrol.com/india/stockpricequote/aluminium/nationalaluminiumcompany/NAC"

# %%
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

# %%
page = requests.get(URL, headers=headers)

# %%
soup1 = BeautifulSoup(page.content,"html.parser")

# %%
print(soup1)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <meta content="1800" http-equiv="refresh"/> <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <title>NALCO Share Price, NALCO Stock Price, National Aluminium Company Ltd. Stock Price, Share Price, Live BSE/NSE, National Aluminium Company Ltd. Bids Offers. Buy/Sell National Aluminium Company Ltd. news &amp; tips, &amp; F&amp;O Quotes, NSE/BSE Forecast News and Live Quotes</title>
# <link href="https://images.moneycontrol.com/images/responsive/common/apple-touch-icon.png" rel="apple-touch-icon"/>
# ...

# %%
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
title = soup2.find("div",class_='inid_name').get_text()

# %%
print(title)
# Out:
#         National Aluminium Company Ltd.
#
#
#         Sector:
#
#
#           Aluminium

# %% [markdown]
# ### Define a function to remove space from the title

# %%
def remove_space(input_string):
    no_white_space = ''
    for c in input_string:
        if not c.isspace():
            no_white_space += c
    return no_white_space

# %%
title = remove_space(title)

# %%
print(title)
# Out:
# NationalAluminiumCompanyLtd.Sector:Aluminium

# %%
CurrentPrice = soup2.find(id='nsecp').get_text()

# %%
CurrentPrice = float(CurrentPrice)

# %%
print(CurrentPrice)
# Out:
# 70.2

# %%
DayRange_low = soup2.find(id='sp_low').get_text()

# %%
print(DayRange_low)
# Out:
#             68.05

# %%
DayRange_high = soup2.find(id='sp_high').get_text()

# %%
print(DayRange_high)
# Out:
#             70.50

# %%
title = remove_space(title)
#CurrentPrice=CurrentPrice.strip()
DayRange_low=DayRange_low.strip()
DayRange_high=DayRange_high.strip()

print(title)
print(CurrentPrice)
print(DayRange_low)
print(DayRange_high)
# Out:
# NationalAluminiumCompanyLtd.Sector:Aluminium
# 70.2
# 68.05
# 70.50

# %% [markdown]
# ### Import datetime library to get present date

# %%
import datetime 
today = datetime.date.today()
print(today)
# Out:
# 2022-10-20

# %% [markdown]
# ### Import csv to get the dataset in csv format

# %%
import csv

header = ['Title','CurrentPrice','DayRange_low','DayRange_high']
data = [title,CurrentPrice,DayRange_low,DayRange_high]

#Do not use thebelow code more than once it will delete content accidently

with open('Nationalalum_dataset.csv','w',newline='',encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %% [markdown]
# ### Read the file here instead of opening the csv file and checking everytime

# %%
import pandas as pd
df = pd.read_csv(r'/Users/vinu/Nationalalum_dataset.csv')
print(df)
# Out:
#                                           Title  CurrentPrice  DayRange_low  \
# 0  NationalAluminiumCompanyLtd.Sector:Aluminium          70.2         68.05
#
#    DayRange_high
# 0           70.5

# %% [markdown]
# ### Now we are appending data to the csv
# ### Remove the header

# %%
# Now we are appending data to the csv
# Remove the header

with open('Nationalalum_dataset.csv','a+',newline='',encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %% [markdown]
# ### Define a function send_mail to alert you through mail when the share price drops below Rs.71

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('rohinikrish2112@gmail.com','jozezeoxpvidsfnt')
    
    subject = "The Share you want is below 71! Now is your chance to buy!"
    body = "Rohini, This is the moment we have been waiting for. Don't mess it up! Link here: https://www.moneycontrol.com/india/stockpricequote/aluminium/nationalaluminiumcompany/NAC"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'rohinikrish2112@gmail.com','rohinikrish2112@gmail.com',
        msg
     #server.sendmail(sender_email, receiver_email, message)
    )

# %% [markdown]
# ### Define a function called check_price - To check the price every so and so minutes as required

# %%
def check_price():
    URL ="https://www.moneycontrol.com/india/stockpricequote/aluminium/nationalaluminiumcompany/NAC"
    
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}
    
    page = requests.get(URL, headers=headers)
    
    soup1 = BeautifulSoup(page.content,"html.parser")
    
    soup2 = BeautifulSoup(soup1.prettify(),"html.parser")
    
    title = soup2.find("div",class_='inid_name').get_text()
    
    CurrentPrice = soup2.find(id='nsecp').get_text()
    
    DayRange_low = soup2.find(id='sp_low').get_text()
    
    DayRange_high = soup2.find(id='sp_high').get_text()
    
    title = remove_space(title)
    CurrentPrice=CurrentPrice.strip()
    DayRange_low=DayRange_low.strip()
    DayRange_high=DayRange_high.strip()
    
    import datetime 
    today = datetime.date.today()
    
    import csv

    header = ['Title','CurrentPrice','DayRange_low','DayRange_high']
    data = [title,CurrentPrice,DayRange_low,DayRange_high]
    
    with open('Nationalalum_dataset.csv','a+',newline='',encoding ='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
   
    #We use this code if we want a mail alert
    if float(CurrentPrice) < 71.0:
                  send_mail()

# %% [markdown]
# ### while loop to check price every 5 seconds

# %%
#This code below checks price for every 5 secs but now we need an alert mail if price goes below 68.5 so we dont need this code now
#while(True):
    #check_price()
    #time.sleep(5)

# %% [markdown]
# ### while loop to check price every 6 hours

# %%
#write the while loop for 6 hours as market open time is 9 am and close time is 3 pm
#1 hour = 60 mins = 3600 secs
#24 hours = 3600 * 6 
#24 hours = 21600 secs
#This will run as long as the computer is working
#Visual studio code is easier for automating these kind of tasks

while(True):
    check_price()
    time.sleep(3600)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cc/1xwxp6d97r39ljyvc_6vp_3w0000gn/T/ipykernel_10789/1023954660.py in <module>
#       8 while(True):
#       9     check_price()
# ---> 10     time.sleep(3600)
#
# KeyboardInterrupt:
